# %%
import json
import pandas as pd

# %%
# JSON에서 필드 추출 후 DataFrame으로 변환하는 함수
def work_preprocessing(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        json_data = json.load(f)

    rows = []
    for work in json_data:
        authorships = work.get("authorships", [])
        first_author = authorships[0] if len(authorships) > 0 else None
        first_institution = (
            first_author.get("institutions", [])[0]
            if first_author and first_author.get("institutions")
            else None
        )

        row = {
            "work_id": work.get("id"),
            "title": work.get("title"),
            "doi": work.get("doi"),
            "publication_date": work.get("publication_date"),
            "type": work.get("type"),
            "is_oa": work.get("open_access", {}).get("is_oa"),
            "primary_topic_id": work.get("primary_topic", {}).get("id"),
            "domain": work.get("primary_topic", {}).get("domain", {}).get("display_name"),
            "field": work.get("primary_topic", {}).get("field", {}).get("display_name"),
            "subfield": work.get("primary_topic", {}).get("subfield", {}).get("display_name"),
            "citations_past_decade": work.get("cited_by_count"),
            "created_date": work.get("created_date"),
            "first_institution_id": first_institution.get("id") if first_institution else None,
            "first_author_id": first_author.get("author", {}).get("id") if first_author else None,
            "keywords": ", ".join([k.get("display_name", "") for k in work.get("keywords", [])]) if work.get("keywords") else None
        }
        rows.append(row)

    return pd.DataFrame(rows)

# %%
file_list = [
    r'D:\devcourse\session2\project\works_20250801_20250820.json',
    r'D:\devcourse\session2\project\works_20250821_20250910.json',
    r'D:\devcourse\session2\project\works_20250911_20250930.json',
    r'D:\devcourse\session2\project\works_20251001_20251022.json'
]

# %%
works_list = [work_preprocessing(file) for file in file_list]

# %%
works = pd.concat(works_list, ignore_index=True)

# %%
works["work_id"] = works["work_id"].str.split("/").str[-1]
works["primary_topic_id"] = works["primary_topic_id"].str.split("/").str[-1]
works["first_institution_id"] = works["first_institution_id"].str.split("/").str[-1]
works["first_author_id"] = works["first_author_id"].str.split("/").str[-1]

# %%
works['publication_date'] = pd.to_datetime(works['publication_date'], errors='coerce')
works['created_date'] = pd.to_datetime(works['created_date'], errors='coerce')

# %%
works.head()
# Out:
#        work_id                                              title  \
# 0  W2419652933  A Critical Appraisal of the Utility of the Ser...
# 1    W63003660             Introduction to Digital Communications
# 2  W4413247502  GetDist: a Python package for analysing Monte ...
# 3  W3187640320                   Blood donation management system
# 4  W3094967386                 Use Cases for In-Network Computing
#
#                                              doi publication_date     type  \
# 0               https://doi.org/10.64719/pb.4221       2025-08-12  article
# 1        https://doi.org/10.1016/c2023-0-01098-6       2025-08-08     book
# 2  https://doi.org/10.1088/1475-7516/2025/08/025       2025-08-01  article
# 3          https://doi.org/10.56726/irjmets81722       2025-08-06  article
# 4               https://doi.org/10.17487/rfc9817       2025-08-01   report
#
#    is_oa primary_topic_id             domain  \
# 0  False           T10211  Physical Sciences
# 1  False           T13816  Physical Sciences
# 2   True           T10136  Physical Sciences
# 3  False           T12735    Social Sciences
# 4  False           T10714  Physical Sciences
#
#                                  field  \
# 0                     Computer Science
# 1                          Engineering
# 2                          Mathematics
# 3  Business, Management and Accounting
# 4                     Computer Science
#
#                                   subfield  citations_past_decade  \
# 0     Computational Theory and Mathematics                     67
# 1    Electrical and Electronic Engineering                     27
# 2               Statistics and Probability                     25
# 3  Management of Technology and Innovation                     20
# 4     Computer Networks and Communications                     17
#
#   created_date first_institution_id first_author_id  \
# 0   2016-06-24           I126307644     A5037478520
# 1   2016-06-24                 None     A5041929088
# 2   2025-08-17                 None     A5080085506
# 3   2021-08-16                 None     A5055236967
# 4   2020-11-09                 None     A5057626571
#
#                                 keywords
# 0  Critical appraisal, Clinical Practice
# 1                                   None
# 2                      Python, Smoothing
# 3           Blood bank, Blood collection
# 4  Interface (matter), Network interface

# %%
works.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147037 entries, 0 to 147036
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   work_id                147037 non-null  object
#  1   title                  147036 non-null  object
#  2   doi                    146470 non-null  object
#  3   publication_date       147037 non-null  datetime64[ns]
#  4   type                   147037 non-null  object
#  5   is_oa                  147037 non-null  bool
#  6   primary_topic_id       147037 non-null  object
#  7   domain                 147037 non-null  object
#  8   field                  147037 non-null  object
#  9   subfield               147037 non-null  object
#  10  citations_past_decade  147037 non-null  int64
#  11  created_date           147037 non-null  datetime64[ns]
#  12  first_institution_id   57100 non-null   object
#  13  first_author_id        142795 non-null  object
#  14  keywords               76412 non-null   object
# dtypes: bool(1), datetime64[ns](2), int64(1), object(11)
# memory usage: 15.8+ MB

# %%
works[works['work_id'] == "W4414430316"]
# Out:
#            work_id                                              title  \
# 35074  W4414430316  Modality-Specific Speech Enhancement and Noise...
#
#                                                   doi publication_date  \
# 35074  https://doi.org/10.21437/interspeech.2025-2581       2025-08-17
#
#           type  is_oa primary_topic_id             domain             field  \
# 35074  article   True           T10860  Physical Sciences  Computer Science
#
#                 subfield  citations_past_decade created_date  \
# 35074  Signal Processing                      0   2025-09-23
#
#       first_institution_id first_author_id  \
# 35074                 None     A5060592139
#
#                                     keywords
# 35074  Modality (human–computer interaction)

# %%
works.drop(index=65461, inplace=True)
works.reset_index(drop=True, inplace=True)

# %%
works.to_csv('works.csv', index=False, date_format='%Y-%m-%d')
